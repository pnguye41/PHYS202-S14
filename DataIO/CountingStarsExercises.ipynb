# %% [markdown]
# # Counting Stars Exercises

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import requests
from StringIO import StringIO
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['fill']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# **1.** Modify the fill function so that it never looks at the same pixel twice. There are at least two ways to do this. Name your new function fastfill. The function prototype might look something like this:
#
# def fastfill(picture, xsize, ysize, xstart, ystart):
#
#     """Faster fill algorithm that doesn't look at any pixel more than once."""
#
# Be sure to include comments and add detail to the docstring to describe what it is doing.

# %%
response = requests.get("http://imgsrc.hubblesite.org/hu/db/images/hs-2004-20-a-large_web.jpg")
pic = Image.open(StringIO(response.content))

def monochrome(picture, threshold):
    black = (0,0,0)
    white = (255,255,255)
    xsize, ysize = picture.size
    temp = picture.load()
    for x in range(xsize):
        for y in range(ysize):
            r,g,b = temp[x,y]
            if r+g+b >= threshold:
                temp[x,y] = black
            else:
                temp[x,y] = white

bwpic = Image.open(StringIO(response.content))

monochrome(bwpic,200+200+200)
plt.imshow(bwpic);

# %%
BLACK = (0,0,0)
RED = (255,0,0)

def fillrec(picture, xsize, ysize, x, y):
    if picture[x,y] != BLACK:
        return
    picture[x,y] = RED
    if x > 0:
        fillrec(picture, xsize, ysize, x-1, y)
    if x < (xsize-1):
        fillrec(picture, xsize, ysize, x+1, y)
    if y > 0:
        fillrec(picture, xsize, ysize, x, y-1)
    if y < (ysize-1):
        fillrec(picture, xsize, ysize, x, y+1)

# %%
fillrec(bwpic, bwpic.size[0], bwpic.size[1], 0, 0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-dbdc811f1bc5> in <module>()
# ----> 1 fillrec(bwpic, bwpic.size[0], bwpic.size[1], 0, 0)
#
# <ipython-input-53-729caaa2c4c8> in fillrec(picture, xsize, ysize, x, y)
#       3
#       4 def fillrec(picture, xsize, ysize, x, y):
# ----> 5     if picture[x,y] != BLACK:
#       6         return
#       7     picture[x,y] = RED
#
# C:\Users\Philipe\Anaconda\lib\site-packages\PIL\Image.pyc in __getattr__(self, name)
#     510             new['data'] = self.tostring()
#     511             return new
# --> 512         raise AttributeError(name)
#     513
#     514     ##
#
# AttributeError: __getitem__
